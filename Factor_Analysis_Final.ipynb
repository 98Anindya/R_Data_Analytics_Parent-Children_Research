# %%
install.packages("psych")
install.packages("lavaan")


# Load necessary libraries
library(psych)
library(lavaan)

# Read the CSV file
data <- read.csv("new_data.csv")

# Define the variables
independent_variables <- c('BFI..E.', 'BFI..A.', 'BFI..C.', 'BFI..N.', 'BFI..O.', 'EI..Self.A.', 'EI..Self.M.', 'EI..Social.A.', 'EI..RM.', 'Total')
dependent_variables <- c('Panas..', 'Panas...1', 'CBCL')
mediator_variables <- 'PAQ'

# 1) Exploratory Factor Analysis
efa <- psych::fa(data[independent_variables], nfactors = 5, rotate = "varimax")
print(efa)

# 2) KMO and Barret test
KMO <- psych::KMO(data[independent_variables])
print(KMO)

# 3) Construct Validity analysis
# Here, we'll use Cronbach's alpha as a measure of construct validity
alpha <- psych::alpha(data[independent_variables])
print(alpha)

# 4) Confirmatory Factor Analysis
# Define the model
model <- ' 
  # latent variable definitions
    f1 =~ BFI..E. + BFI..A. + BFI..C. + BFI..N. + BFI..O.
    f2 =~ EI..Self.A. + EI..Self.M. + EI..Social.A. + EI..RM. + Total
  # regressions
    Panas.. + Panas...1 + CBCL ~ f1 + f2
    PAQ ~ f1 + f2
  # residual correlations
    Panas.. ~~ Panas...1 + CBCL
    Panas...1 ~~ CBCL
'
fit <- lavaan::cfa(model, data = data)
summary(fit, fit.measures = TRUE)
# Out:
# also installing the dependency ‘mnormt’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# also installing the dependencies ‘pbivnorm’, ‘quadprog’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# This is lavaan 0.6-17
# lavaan is FREE software! Please report any bugs.
#
#
# Attaching package: ‘lavaan’
#
#
# The following object is masked from ‘package:psych’:
#
#     cor2cov
#
#
# Warning message in fa.stats(r = r, f = f, phi = phi, n.obs = n.obs, np.obs = np.obs, :
# “The estimated weights for the factor scores are probably incorrect.  Try a different factor score estimation method.”
# Warning message in fac(r = r, nfactors = nfactors, n.obs = n.obs, rotate = rotate, :
# “An ultra-Heywood case was detected.  Examine the results carefully”
# Factor Analysis using method =  minres
# Call: psych::fa(r = data[independent_variables], nfactors = 5, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#                 MR1   MR2   MR3   MR4   MR5   h2     u2 com
# BFI..E.       -0.07  0.15  0.06  0.88 -0.01 0.80  0.197 1.1
# BFI..A.       -0.17  0.55  0.23  0.01  0.03 0.39  0.615 1.5
# BFI..C.       -0.12  0.76  0.01  0.08  0.12 0.61  0.388 1.1
# BFI..N.        0.07 -0.46  0.01 -0.09  0.15 0.25  0.752 1.4
# BFI..O.       -0.17  0.13  0.97  0.07 -0.01 0.99  0.005 1.1
# EI..Self.A.    0.55 -0.07 -0.07  0.05  0.12 0.32  0.675 1.2
# EI..Self.M.    0.59 -0.42 -0.26 -0.12  0.27 0.68  0.315 2.8
# EI..Social.A.  0.80 -0.08 -0.02 -0.05 -0.27 0.73  0.273 1.3
# EI..RM.        0.76 -0.14 -0.07 -0.11 -0.08 0.62  0.378 1.2
# Total          0.95 -0.24 -0.15 -0.05  0.17 1.02 -0.024 1.3
#
#                        MR1  MR2  MR3  MR4  MR5
# SS loadings           2.86 1.40 1.10 0.83 0.23
# Proportion Var        0.29 0.14 0.11 0.08 0.02
# Cumulative Var        0.29 0.43 0.54 0.62 0.64
# Proportion Explained  0.45 0.22 0.17 0.13 0.04
# Cumulative Proportion 0.45 0.66 0.84 0.96 1.00
#
# Mean item complexity =  1.4
# Test of the hypothesis that 5 factors are sufficient.
#
# df null model =  45  with the objective function =  4.31 with Chi Square =  8602.99
# df of  the model are 5  and the objective function was  0.06
#
# The root mean square of the residuals (RMSR) is  0.01
# The df corrected root mean square of the residuals is  0.02
#
# The harmonic n.obs is  2000 with the empirical chi square  10.21  with prob <  0.07
# The total n.obs was  2000  with Likelihood Chi Square =  122.27  with prob <  1e-24
#
# Tucker Lewis Index of factoring reliability =  0.876
# RMSEA index =  0.108  and the 90 % confidence intervals are  0.092 0.125
# BIC =  84.26
# Fit based upon off diagonal values = 1Kaiser-Meyer-Olkin factor adequacy
# Call: psych::KMO(r = data[independent_variables])
# Overall MSA =  0.75
# MSA for each item =
#       BFI..E.       BFI..A.       BFI..C.       BFI..N.       BFI..O.
#          0.74          0.81          0.77          0.78          0.83
#   EI..Self.A.   EI..Self.M. EI..Social.A.       EI..RM.         Total
#          0.84          0.71          0.79          0.80          0.67
# Warning message in psych::alpha(data[independent_variables]):
# “Some items were negatively correlated with the first principal component and probably
# should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option”
# Some items ( BFI..E. BFI..A. BFI..C. BFI..O. ) were negatively correlated with the first principal component and
# probably should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option
# Reliability analysis
# Call: psych::alpha(x = data[independent_variables])
#
#   raw_alpha std.alpha G6(smc) average_r  S/N    ase mean  sd median_r
#       0.65      0.37    0.62     0.056 0.59 0.0066   31 3.3   -0.076
#
#     95% confidence boundaries
#          lower alpha upper
# Feldt     0.62  0.65  0.67
# Duhachek  0.63  0.65  0.66
#
#  Reliability if an item is dropped:
#               raw_alpha std.alpha G6(smc) average_r  S/N alpha se var.r  med.r
# BFI..E.            0.66      0.44    0.68     0.080 0.79   0.0067 0.142 -0.015
# BFI..A.            0.66      0.46    0.67     0.088 0.87   0.0066 0.126  0.018
# BFI..C.            0.66      0.47    0.67     0.091 0.90   0.0066 0.127  0.018
# BFI..N.            0.65      0.41    0.65     0.072 0.70   0.0068 0.139 -0.101
# BFI..O.            0.66      0.48    0.68     0.092 0.91   0.0066 0.130  0.018
# EI..Self.A.        0.58      0.21    0.55     0.029 0.27   0.0070 0.129 -0.129
# EI..Self.M.        0.58      0.29    0.53     0.043 0.40   0.0068 0.101 -0.086
# EI..Social.A.      0.52      0.18    0.50     0.024 0.23   0.0084 0.112 -0.086
# EI..RM.            0.51      0.18    0.50     0.025 0.23   0.0091 0.107 -0.086
# Total              0.63      0.12    0.38     0.015 0.13   0.0071 0.084 -0.086
#
#  Item statistics
#                  n raw.r std.r  r.cor r.drop mean    sd
# BFI..E.       2000 -0.17 0.161 -0.092  -0.18  1.9  0.46
# BFI..A.       2000 -0.31 0.091 -0.115  -0.32  1.7  0.54
# BFI..C.       2000 -0.29 0.063 -0.146  -0.31  1.7  0.50
# BFI..N.       2000  0.20 0.237  0.032   0.19  2.2  0.52
# BFI..O.       2000 -0.33 0.050 -0.188  -0.34  2.0  0.38
# EI..Self.A.   2000  0.66 0.633  0.590   0.49 78.0  7.51
# EI..Self.M.   2000  0.80 0.512  0.558   0.55 69.5 13.50
# EI..Social.A. 2000  0.79 0.680  0.737   0.65 76.4  9.14
# EI..RM.       2000  0.83 0.679  0.746   0.66 71.0 11.39
# Total         2000  0.94 0.771  0.940   0.94  3.0  0.96
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# BFI..E. 0.15 0.79 0.07 0.00 0.00    0
# BFI..A. 0.37 0.60 0.03 0.00 0.00    0
# BFI..C. 0.35 0.64 0.01 0.00 0.00    0
# BFI..N. 0.05 0.68 0.27 0.00 0.00    0
# BFI..O. 0.09 0.85 0.06 0.00 0.00    0
# Total   0.05 0.27 0.32 0.33 0.03    0
# Warning message in lav_data_full(data = data, group = group, cluster = cluster, :
# “lavaan WARNING: some observed variances are (at least) a factor 1000 times larger than others; use varTable(fit) to investigate”
# Warning message in lav_object_post_check(object):
# “lavaan WARNING: some estimated ov variances are negative”
# lavaan 0.6.17 ended normally after 174 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of model parameters                        39
#
#   Number of observations                          2000
#
# Model Test User Model:
#
#   Test statistic                              1439.799
#   Degrees of freedom                                66
#   P-value (Chi-square)                           0.000
#
# Model Test Baseline Model:
#
#   Test statistic                              9561.146
#   Degrees of freedom                                91
#   P-value                                        0.000
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.855
#   Tucker-Lewis Index (TLI)                       0.800
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)             -42628.018
#   Loglikelihood unrestricted model (H1)     -41908.118
#
#   Akaike (AIC)                               85334.036
#   Bayesian (BIC)                             85552.471
#   Sample-size adjusted Bayesian (SABIC)      85428.566
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.102
#   90 Percent confidence interval - lower         0.097
#   90 Percent confidence interval - upper         0.107
#   P-value H_0: RMSEA <= 0.050                    0.000
#   P-value H_0: RMSEA >= 0.080                    1.000
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.064
#
# Parameter Estimates:
#
#   Standard errors                             Standard
#   Information                                 Expected
#   Information saturated (h1) model          Structured
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   f1 =~
#     BFI..E.           1.000
#     BFI..A.           3.403    0.389    8.758    0.000
#     BFI..C.           2.827    0.326    8.686    0.000
#     BFI..N.          -2.052    0.253   -8.125    0.000
#     BFI..O.           1.405    0.176    7.986    0.000
#   f2 =~
#     EI..Self.A.       1.000
#     EI..Self.M.       2.477    0.090   27.372    0.000
#     EI..Social.A.     1.571    0.060   26.351    0.000
#     EI..RM.           2.035    0.075   26.959    0.000
#     Total             0.240    0.008   30.767    0.000
#
# Regressions:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   Panas.. ~
#     f1                0.728    0.186    3.915    0.000
#     f2               -0.008    0.003   -2.375    0.018
#   Panas...1 ~
#     f1                0.137    0.119    1.151    0.250
#     f2                0.008    0.002    3.160    0.002
#   CBCL ~
#     f1               -2.320    0.323   -7.191    0.000
#     f2               -0.002    0.004   -0.359    0.720
#   PAQ ~
#     f1                0.693    0.231    3.001    0.003
#     f2               -0.016    0.005   -3.442    0.001
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#  .Panas.. ~~
#    .Panas...1         0.000    0.005    0.081    0.936
#    .CBCL             -0.078    0.009   -8.319    0.000
#  .Panas...1 ~~
#    .CBCL              0.021    0.006    3.234    0.001
#   f1 ~~
#     f2               -0.201    0.026   -7.745    0.000
#  .Panas.. ~~
#    .PAQ              -0.077    0.010   -7.729    0.000
#  .Panas...1 ~~
#    .PAQ              -0.046    0.007   -6.593    0.000
#  .CBCL ~~
#    .PAQ               0.019    0.012    1.589    0.112
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#    .BFI..E.           0.196    0.006   30.845    0.000
#    .BFI..A.           0.150    0.008   19.312    0.000
#    .BFI..C.           0.151    0.007   23.085    0.000
#    .BFI..N.           0.222    0.008   28.680    0.000
#    .BFI..O.           0.122    0.004   29.121    0.000
#    .EI..Self.A.      39.038    1.194   32.700    0.000
#    .EI..Self.M.      75.962    2.348   32.347    0.000
#    .EI..Social.A.    40.796    1.245   32.755    0.000
#    .EI..RM.          57.994    1.781   32.562    0.000
#    .Total            -0.078    0.006  -11.995    0.000
#    .Panas..           0.336    0.011   31.345    0.000
#    .Panas...1         0.167    0.005   31.624    0.000
#    .CBCL              0.462    0.016   29.557    0.000
#    .PAQ               0.568    0.018   31.493    0.000
#     f1                0.012    0.003    4.556    0.000
#     f2               17.313    1.246   13.894    0.000

# %%
install.packages("psych")
install.packages("lavaan")


# Load necessary libraries
library(psych)
library(lavaan)

# Read the CSV file
data <- read.csv("new_data.csv")

# Define the variables
independent_variables <- c('BFI..E.', 'BFI..A.', 'BFI..C.', 'BFI..N.', 'BFI..O.', 'EI..Self.A.', 'EI..Self.M.', 'EI..Social.A.', 'EI..RM.', 'Total')
dependent_variables <- c('Panas..', 'Panas...1', 'CBCL')
mediator_variables <- 'PAQ'

# 1) Exploratory Factor Analysis
efa <- psych::fa(data[independent_variables], nfactors = 8, rotate = "varimax")
print(efa)

# 2) KMO and Barret test
KMO <- psych::KMO(data[independent_variables])
print(KMO)

# 3) Construct Validity analysis
# Here, we'll use Cronbach's alpha as a measure of construct validity
alpha <- psych::alpha(data[independent_variables])
print(alpha)

# 4) Confirmatory Factor Analysis
# Define the model
model <- ' 
  # latent variable definitions
    f1 =~ BFI..E. + BFI..A. + BFI..C. + BFI..N. + BFI..O.
    f2 =~ EI..Self.A. + EI..Self.M. + EI..Social.A. + EI..RM. + Total
  # regressions
    Panas.. + Panas...1 + CBCL ~ f1 + f2
    PAQ ~ f1 + f2
  # residual correlations
    Panas.. ~~ Panas...1 + CBCL
    Panas...1 ~~ CBCL
'
fit <- lavaan::cfa(model, data = data)
summary(fit, fit.measures = TRUE)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# Factor Analysis using method =  minres
# Call: psych::fa(r = data[independent_variables], nfactors = 8, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#                 MR1   MR2   MR3   MR8   MR5   MR4   MR6   MR7   h2    u2 com
# BFI..E.       -0.06  0.11  0.09 -0.04  0.50 -0.07  0.00  0.01 0.28 0.715 1.2
# BFI..A.       -0.13  0.64  0.35  0.00  0.00 -0.06 -0.01 -0.01 0.56 0.443 1.7
# BFI..C.       -0.12  0.65  0.00 -0.12  0.19 -0.16  0.01  0.01 0.52 0.484 1.5
# BFI..N.        0.05 -0.36  0.00  0.07 -0.15  0.46  0.01  0.02 0.37 0.630 2.2
# BFI..O.       -0.15  0.13  0.64 -0.09  0.12  0.01 -0.01 -0.02 0.47 0.534 1.3
# EI..Self.A.    0.54 -0.03 -0.13  0.09  0.09  0.12  0.00  0.26 0.41 0.590 1.9
# EI..Self.M.    0.48 -0.28 -0.37  0.60 -0.19  0.17 -0.01  0.04 0.88 0.123 3.6
# EI..Social.A.  0.82 -0.15 -0.02  0.04 -0.09 -0.13 -0.21 -0.10 0.78 0.222 1.3
# EI..RM.        0.80 -0.12 -0.11 -0.01 -0.19  0.05  0.24 -0.08 0.78 0.222 1.4
# Total          0.89 -0.16 -0.24  0.29 -0.08  0.15  0.01  0.06 0.99 0.005 1.6
#
#                        MR1  MR2  MR3  MR8  MR5  MR4  MR6  MR7
# SS loadings           2.69 1.14 0.76 0.49 0.43 0.33 0.10 0.09
# Proportion Var        0.27 0.11 0.08 0.05 0.04 0.03 0.01 0.01
# Cumulative Var        0.27 0.38 0.46 0.51 0.55 0.58 0.59 0.60
# Proportion Explained  0.45 0.19 0.13 0.08 0.07 0.05 0.02 0.01
# Cumulative Proportion 0.45 0.63 0.76 0.84 0.91 0.97 0.99 1.00
#
# Mean item complexity =  1.8
# Test of the hypothesis that 8 factors are sufficient.
#
# df null model =  45  with the objective function =  4.31 with Chi Square =  8602.99
# df of  the model are -7  and the objective function was  0
#
# The root mean square of the residuals (RMSR) is  0
# The df corrected root mean square of the residuals is  NA
#
# The harmonic n.obs is  2000 with the empirical chi square  0  with prob <  NA
# The total n.obs was  2000  with Likelihood Chi Square =  0  with prob <  NA
#
# Tucker Lewis Index of factoring reliability =  1.005
# Fit based upon off diagonal values = 1
# Measures of factor score adequacy
#                                                    MR1  MR2  MR3  MR8   MR5
# Correlation of (regression) scores with factors   0.97 0.79 0.71 0.76  0.60
# Multiple R square of scores with factors          0.95 0.62 0.50 0.58  0.36
# Minimum correlation of possible factor scores     0.90 0.24 0.00 0.17 -0.28
#                                                     MR4   MR6   MR7
# Correlation of (regression) scores with factors    0.58  0.55  0.39
# Multiple R square of scores with factors           0.33  0.30  0.15
# Minimum correlation of possible factor scores     -0.33 -0.40 -0.69
# Kaiser-Meyer-Olkin factor adequacy
# Call: psych::KMO(r = data[independent_variables])
# Overall MSA =  0.75
# MSA for each item =
#       BFI..E.       BFI..A.       BFI..C.       BFI..N.       BFI..O.
#          0.74          0.81          0.77          0.78          0.83
#   EI..Self.A.   EI..Self.M. EI..Social.A.       EI..RM.         Total
#          0.84          0.71          0.79          0.80          0.67
# Warning message in psych::alpha(data[independent_variables]):
# “Some items were negatively correlated with the first principal component and probably
# should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option”
# Some items ( BFI..E. BFI..A. BFI..C. BFI..O. ) were negatively correlated with the first principal component and
# probably should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option
# Reliability analysis
# Call: psych::alpha(x = data[independent_variables])
#
#   raw_alpha std.alpha G6(smc) average_r  S/N    ase mean  sd median_r
#       0.65      0.37    0.62     0.056 0.59 0.0066   31 3.3   -0.076
#
#     95% confidence boundaries
#          lower alpha upper
# Feldt     0.62  0.65  0.67
# Duhachek  0.63  0.65  0.66
#
#  Reliability if an item is dropped:
#               raw_alpha std.alpha G6(smc) average_r  S/N alpha se var.r  med.r
# BFI..E.            0.66      0.44    0.68     0.080 0.79   0.0067 0.142 -0.015
# BFI..A.            0.66      0.46    0.67     0.088 0.87   0.0066 0.126  0.018
# BFI..C.            0.66      0.47    0.67     0.091 0.90   0.0066 0.127  0.018
# BFI..N.            0.65      0.41    0.65     0.072 0.70   0.0068 0.139 -0.101
# BFI..O.            0.66      0.48    0.68     0.092 0.91   0.0066 0.130  0.018
# EI..Self.A.        0.58      0.21    0.55     0.029 0.27   0.0070 0.129 -0.129
# EI..Self.M.        0.58      0.29    0.53     0.043 0.40   0.0068 0.101 -0.086
# EI..Social.A.      0.52      0.18    0.50     0.024 0.23   0.0084 0.112 -0.086
# EI..RM.            0.51      0.18    0.50     0.025 0.23   0.0091 0.107 -0.086
# Total              0.63      0.12    0.38     0.015 0.13   0.0071 0.084 -0.086
#
#  Item statistics
#                  n raw.r std.r  r.cor r.drop mean    sd
# BFI..E.       2000 -0.17 0.161 -0.092  -0.18  1.9  0.46
# BFI..A.       2000 -0.31 0.091 -0.115  -0.32  1.7  0.54
# BFI..C.       2000 -0.29 0.063 -0.146  -0.31  1.7  0.50
# BFI..N.       2000  0.20 0.237  0.032   0.19  2.2  0.52
# BFI..O.       2000 -0.33 0.050 -0.188  -0.34  2.0  0.38
# EI..Self.A.   2000  0.66 0.633  0.590   0.49 78.0  7.51
# EI..Self.M.   2000  0.80 0.512  0.558   0.55 69.5 13.50
# EI..Social.A. 2000  0.79 0.680  0.737   0.65 76.4  9.14
# EI..RM.       2000  0.83 0.679  0.746   0.66 71.0 11.39
# Total         2000  0.94 0.771  0.940   0.94  3.0  0.96
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# BFI..E. 0.15 0.79 0.07 0.00 0.00    0
# BFI..A. 0.37 0.60 0.03 0.00 0.00    0
# BFI..C. 0.35 0.64 0.01 0.00 0.00    0
# BFI..N. 0.05 0.68 0.27 0.00 0.00    0
# BFI..O. 0.09 0.85 0.06 0.00 0.00    0
# Total   0.05 0.27 0.32 0.33 0.03    0
# Warning message in lav_data_full(data = data, group = group, cluster = cluster, :
# “lavaan WARNING: some observed variances are (at least) a factor 1000 times larger than others; use varTable(fit) to investigate”
# Warning message in lav_object_post_check(object):
# “lavaan WARNING: some estimated ov variances are negative”
# lavaan 0.6.17 ended normally after 174 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of model parameters                        39
#
#   Number of observations                          2000
#
# Model Test User Model:
#
#   Test statistic                              1439.799
#   Degrees of freedom                                66
#   P-value (Chi-square)                           0.000
#
# Model Test Baseline Model:
#
#   Test statistic                              9561.146
#   Degrees of freedom                                91
#   P-value                                        0.000
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.855
#   Tucker-Lewis Index (TLI)                       0.800
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)             -42628.018
#   Loglikelihood unrestricted model (H1)     -41908.118
#
#   Akaike (AIC)                               85334.036
#   Bayesian (BIC)                             85552.471
#   Sample-size adjusted Bayesian (SABIC)      85428.566
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.102
#   90 Percent confidence interval - lower         0.097
#   90 Percent confidence interval - upper         0.107
#   P-value H_0: RMSEA <= 0.050                    0.000
#   P-value H_0: RMSEA >= 0.080                    1.000
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.064
#
# Parameter Estimates:
#
#   Standard errors                             Standard
#   Information                                 Expected
#   Information saturated (h1) model          Structured
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   f1 =~
#     BFI..E.           1.000
#     BFI..A.           3.403    0.389    8.758    0.000
#     BFI..C.           2.827    0.326    8.686    0.000
#     BFI..N.          -2.052    0.253   -8.125    0.000
#     BFI..O.           1.405    0.176    7.986    0.000
#   f2 =~
#     EI..Self.A.       1.000
#     EI..Self.M.       2.477    0.090   27.372    0.000
#     EI..Social.A.     1.571    0.060   26.351    0.000
#     EI..RM.           2.035    0.075   26.959    0.000
#     Total             0.240    0.008   30.767    0.000
#
# Regressions:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   Panas.. ~
#     f1                0.728    0.186    3.915    0.000
#     f2               -0.008    0.003   -2.375    0.018
#   Panas...1 ~
#     f1                0.137    0.119    1.151    0.250
#     f2                0.008    0.002    3.160    0.002
#   CBCL ~
#     f1               -2.320    0.323   -7.191    0.000
#     f2               -0.002    0.004   -0.359    0.720
#   PAQ ~
#     f1                0.693    0.231    3.001    0.003
#     f2               -0.016    0.005   -3.442    0.001
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#  .Panas.. ~~
#    .Panas...1         0.000    0.005    0.081    0.936
#    .CBCL             -0.078    0.009   -8.319    0.000
#  .Panas...1 ~~
#    .CBCL              0.021    0.006    3.234    0.001
#   f1 ~~
#     f2               -0.201    0.026   -7.745    0.000
#  .Panas.. ~~
#    .PAQ              -0.077    0.010   -7.729    0.000
#  .Panas...1 ~~
#    .PAQ              -0.046    0.007   -6.593    0.000
#  .CBCL ~~
#    .PAQ               0.019    0.012    1.589    0.112
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#    .BFI..E.           0.196    0.006   30.845    0.000
#    .BFI..A.           0.150    0.008   19.312    0.000
#    .BFI..C.           0.151    0.007   23.085    0.000
#    .BFI..N.           0.222    0.008   28.680    0.000
#    .BFI..O.           0.122    0.004   29.121    0.000
#    .EI..Self.A.      39.038    1.194   32.700    0.000
#    .EI..Self.M.      75.962    2.348   32.347    0.000
#    .EI..Social.A.    40.796    1.245   32.755    0.000
#    .EI..RM.          57.994    1.781   32.562    0.000
#    .Total            -0.078    0.006  -11.995    0.000
#    .Panas..           0.336    0.011   31.345    0.000
#    .Panas...1         0.167    0.005   31.624    0.000
#    .CBCL              0.462    0.016   29.557    0.000
#    .PAQ               0.568    0.018   31.493    0.000
#     f1                0.012    0.003    4.556    0.000
#     f2               17.313    1.246   13.894    0.000
